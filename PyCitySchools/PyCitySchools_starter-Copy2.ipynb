# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

#copy of school and student dataframes
copy_school=school_data.copy()
copy_student = student_data.copy()

# %%
#print dimensions of school_data
print("school_data dimensions: {}".format(school_data.shape))
# Out:
# school_data dimensions: (15, 5)

# %%
#print value_counts
school_data['school_name'].isin(student_data['school_name']).value_counts()
# Out:
# True    15
# Name: school_name, dtype: int64

# %%
school_data
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
#print dimensions of student_data
print("student_data dimensions: {}".format(student_data.shape))
# Out:
# student_data dimensions: (39170, 7)

# %%
student_data
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# ...

# %%
# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
#Calculate total number of schools
count_schools = len(school_data_complete["school_name"].unique())
count_schools
# Out:
# 15

# %%
#Calculate total number of student
count_students = len(school_data_complete["Student ID"].unique())
count_students = "{:,}".format(count_students)
count_students
# Out:
# '39,170'

# %%
#Calculate total budget using dataframe school_data
total_budget = school_data["budget"].sum()
total_budget = "${:,.2f}".format(total_budget)
total_budget
# Out:
# '$24,649,428.00'

# %%
#Calculate the average math score by using mean
avg_math_score = round((student_data["math_score"].mean()), 6)
avg_math_score
# Out:
# 78.985371

# %%
#Calculate the average reading score by using mean
avg_reading_score = round((student_data["reading_score"].mean()), 5)
avg_reading_score
# Out:
# 81.87784

# %%
#Calculate the percentage of students with a passing math and reading score (70 or greater)
student_data["passing_math"] = student_data["math_score"]>=70
student_data["passing_reading"] = student_data["reading_score"]>=70
pct_passing_math = round(((student_data["passing_math"]).mean())*100,6)
pct_passing_reading = round(((student_data["passing_reading"]).mean())*100,6)
#pct_passing_math = "{:.6f}".format(pct_passing_math)
#pct_passing_reading = "{:.6f}".format(pct_passing_reading)
pct_passing_math
# Out:
# 74.980853

# %%
pct_passing_reading
# Out:
# 85.805463

# %%
#Calculate Overall Passing students
student_data["overall_passing"] = student_data["passing_math"] & student_data["passing_reading"]
pct_overall_passing = round(((student_data["overall_passing"]).mean())*100,6)
pct_overall_passing
# Out:
# 65.172326

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
district_summary_df = pd.DataFrame({"Total Schools":[count_schools], "Total Students":[count_students],
                                   "Total Budget":[total_budget] , "Average Math Score": [avg_math_score] , 
                                    "Average Reading Score": [avg_reading_score], "% Passing Math": [pct_passing_math], 
                                   "% Passing Reading":[pct_passing_reading], 
                                    "% Overall Passing": [pct_overall_passing]})
district_summary_df
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
del copy_school["School ID"]
copy_school
# Out:
#               school_name      type  size   budget
# 0       Huang High School  District  2917  1910635
# 1    Figueroa High School  District  2949  1884411
# 2     Shelton High School   Charter  1761  1056600
# 3   Hernandez High School  District  4635  3022020
# 4     Griffin High School   Charter  1468   917500
# 5      Wilson High School   Charter  2283  1319574
# 6     Cabrera High School   Charter  1858  1081356
# 7      Bailey High School  District  4976  3124928
# 8      Holden High School   Charter   427   248087
# 9        Pena High School   Charter   962   585858
# 10     Wright High School   Charter  1800  1049400
# 11  Rodriguez High School  District  3999  2547363
# 12    Johnson High School  District  4761  3094650
# 13       Ford High School  District  2739  1763916
# 14     Thomas High School   Charter  1635  1043130

# %%
del copy_student["Student ID"]
copy_student
# Out:
#             student_name gender grade         school_name  reading_score  \
# 0           Paul Bradley      M   9th   Huang High School             66
# 1           Victor Smith      M  12th   Huang High School             94
# 2        Kevin Rodriguez      M  12th   Huang High School             90
# 3      Dr. Richard Scott      M  12th   Huang High School             67
# 4             Bonnie Ray      F   9th   Huang High School             97
# ...                  ...    ...   ...                 ...            ...
# 39165       Donna Howard      F  12th  Thomas High School             99
# 39166          Dawn Bell      F  10th  Thomas High School             95
# 39167     Rebecca Tanner      F   9th  Thomas High School             73
# 39168       Desiree Kidd      F  10th  Thomas High School             99
# 39169    Carolyn Jackson      F  11th  Thomas High School             95
#
#        math_score
# 0              79
# 1              61
# 2              60
# ...

# %%
copy_school["Per Student Budget"] = copy_school["budget"]/copy_school["size"]
copy_school
# Out:
#               school_name      type  size   budget  Per Student Budget
# 0       Huang High School  District  2917  1910635               655.0
# 1    Figueroa High School  District  2949  1884411               639.0
# 2     Shelton High School   Charter  1761  1056600               600.0
# 3   Hernandez High School  District  4635  3022020               652.0
# 4     Griffin High School   Charter  1468   917500               625.0
# 5      Wilson High School   Charter  2283  1319574               578.0
# 6     Cabrera High School   Charter  1858  1081356               582.0
# 7      Bailey High School  District  4976  3124928               628.0
# 8      Holden High School   Charter   427   248087               581.0
# 9        Pena High School   Charter   962   585858               609.0
# 10     Wright High School   Charter  1800  1049400               583.0
# 11  Rodriguez High School  District  3999  2547363               637.0
# ...

# %%
avg_math_scores = copy_student.groupby(['school_name'])['math_score'].mean()
avg_reading_scores = copy_student.groupby(['school_name'])['reading_score'].mean()

# %%
copy_school = copy_school.merge(avg_math_scores, on = "school_name", how = "inner")

# %%
copy_school = copy_school.merge(avg_reading_scores, on = "school_name", how = "inner")
copy_school
# Out:
#               school_name      type  size   budget  Per Student Budget  \
# 0       Huang High School  District  2917  1910635               655.0
# 1    Figueroa High School  District  2949  1884411               639.0
# 2     Shelton High School   Charter  1761  1056600               600.0
# 3   Hernandez High School  District  4635  3022020               652.0
# 4     Griffin High School   Charter  1468   917500               625.0
# 5      Wilson High School   Charter  2283  1319574               578.0
# 6     Cabrera High School   Charter  1858  1081356               582.0
# 7      Bailey High School  District  4976  3124928               628.0
# 8      Holden High School   Charter   427   248087               581.0
# 9        Pena High School   Charter   962   585858               609.0
# 10     Wright High School   Charter  1800  1049400               583.0
# 11  Rodriguez High School  District  3999  2547363               637.0
# ...

# %%
summary_passing_math = copy_student[copy_student["math_score"]>=70]
summary_passing_reading = copy_student[copy_student["reading_score"]>=70]

# %%
copy_school["% Passing Math"] = round((copy_school["passing_math"])*100,2)
copy_school
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'passing_math'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-72350e35ff17> in <module>
# ...

# %%
#groupby by school_name
group_school = school_data_complete.groupby(['school_name']).mean()
group_school

# %%
group_school["% Passing Reading"] = round((group_school["passing_reading"])*100,2)
group_school["% Passing Reading"]

# %%
#using .rename(columns = {}) in order to renmae columns
group_school_renamed = group_school.rename(columns = {"type": "School Type","size": "Total Students", 
                                                    "budget": "Total School Budget",})

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
